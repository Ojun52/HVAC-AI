# %%
import sys
from datetime import datetime

import gymnasium as gym
import numpy as np
import wandb
from stable_baselines3 import *
from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.logger import HumanOutputFormat
from stable_baselines3.common.logger import Logger as SB3Logger

import sinergym
from sinergym.utils.callbacks import *
from sinergym.utils.constants import *
from sinergym.utils.logger import WandBOutputFormat
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import *

# %%
from stable_baselines3.common.env_util import make_vec_env

# %%
# Environment ID
environment = 'Eplus-office-mixed-continuous-stochastic-v1'

# Training episodes
episodes = 100

# Name of the experiment
experiment_date = datetime.today().strftime('%Y-%m-%d_%H:%M')
experiment_name = 'SB3_PPO-' + environment + \
    '-episodes-' + str(episodes)
experiment_name += '_' + experiment_date

# %%
extra_conf = {
    'timesteps_per_hour': 6,
    'runperiod': (1, 7, 2024, 31, 7, 2024),
}

# %%
env = gym.make(environment,
               env_name=experiment_name,
               weather_files=["JPN_Nagoya.476350_IWEC.epw"],
               reward=LinearReward,
               reward_kwargs = {
                   "energy_weight": 0.5,
                   'temperature_variables': ['perimeter_bot_zn_1_air_temperature',
                     'perimeter_bot_zn_2_air_temperature',
                     'perimeter_bot_zn_3_air_temperature',
                     'perimeter_bot_zn_4_air_temperature',
                     'perimeter_mid_zn_1_air_temperature',
                     'perimeter_mid_zn_2_air_temperature',
                     'perimeter_mid_zn_3_air_temperature',
                     'perimeter_mid_zn_4_air_temperature',
                     'perimeter_top_zn_1_air_temperature',
                     'perimeter_top_zn_2_air_temperature',
                     'perimeter_top_zn_3_air_temperature',
                     'perimeter_top_zn_4_air_temperature',
                                            ],
                   'energy_variables': ['HVAC_electricity_demand_rate'],
                   "range_comfort_winter": (20.0, 23.5),
                   "range_comfort_summer": (23.0, 26.0),
                   "lambda_energy": 0.0001,
               },
              building_config=extra_conf,)

eval_env = gym.make(environment,
                    env_name=experiment_name+'_EVALUATION',
                    weather_files=["JPN_Nagoya.476350_IWEC.epw"],
                    reward=LinearReward,
                    reward_kwargs = {
                        "energy_weight": 0.5,
                        'temperature_variables': ['perimeter_bot_zn_1_air_temperature',
                         'perimeter_bot_zn_2_air_temperature',
                         'perimeter_bot_zn_3_air_temperature',
                         'perimeter_bot_zn_4_air_temperature',
                         'perimeter_mid_zn_1_air_temperature',
                         'perimeter_mid_zn_2_air_temperature',
                         'perimeter_mid_zn_3_air_temperature',
                         'perimeter_mid_zn_4_air_temperature',
                         'perimeter_top_zn_1_air_temperature',
                         'perimeter_top_zn_2_air_temperature',
                         'perimeter_top_zn_3_air_temperature',
                         'perimeter_top_zn_4_air_temperature',
                                                 ],
                        'energy_variables': ['HVAC_electricity_demand_rate'],
                        "range_comfort_winter": (20.0, 23.5),
                        "range_comfort_summer": (23.0, 26.0),
                        "lambda_energy": 0.0001,
                    },
                   building_config=extra_conf,)
# Out:
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment.
# [ENVIRONMENT] (INFO) : Name: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #==============================================================================================#
# [MODEL] (INFO) : Working directory created: /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1
# [MODEL] (INFO) : Model Config is correct.
# [MODEL] (INFO) : Building model Output:Variable updated with defined variable names.
# [MODEL] (INFO) : Updated building model Output:Meter with meter names.
# [MODEL] (INFO) : Building configuration: runperiod updated to {'start_day': 1, 'start_month': 7, 'start_year': 2024, 'end_day': 31, 'end_month': 7, 'end_year': 2024, 'start_weekday': 6, 'n_steps_per_hour': 6}
# [MODEL] (INFO) : Updated episode length (seconds): 2678400.0
# [MODEL] (INFO) : Updated timestep size (seconds): 600.0
# [MODEL] (INFO) : Updated timesteps per episode: 4464
# [MODEL] (INFO) : Runperiod established.
# [MODEL] (INFO) : Episode length (seconds): 2678400.0
# [MODEL] (INFO) : timestep size (seconds): 600.0
# [MODEL] (INFO) : timesteps per episode: 4464
# [REWARD] (INFO) : Reward function initialized.
# [ENVIRONMENT] (INFO) : Environment created successfully.
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment.
# [ENVIRONMENT] (INFO) : Name: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #==============================================================================================#
# [MODEL] (INFO) : Working directory created: /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1
# [MODEL] (INFO) : Model Config is correct.
# [MODEL] (INFO) : Building model Output:Variable updated with defined variable names.
# [MODEL] (INFO) : Updated building model Output:Meter with meter names.
# [MODEL] (INFO) : Building configuration: runperiod updated to {'start_day': 1, 'start_month': 7, 'start_year': 2024, 'end_day': 31, 'end_month': 7, 'end_year': 2024, 'start_weekday': 6, 'n_steps_per_hour': 6}
# [MODEL] (INFO) : Updated episode length (seconds): 2678400.0
# [MODEL] (INFO) : Updated timestep size (seconds): 600.0
# [MODEL] (INFO) : Updated timesteps per episode: 4464
# [MODEL] (INFO) : Runperiod established.
# [MODEL] (INFO) : Episode length (seconds): 2678400.0
# [MODEL] (INFO) : timestep size (seconds): 600.0
# [MODEL] (INFO) : timesteps per episode: 4464
# [REWARD] (INFO) : Reward function initialized.
# [ENVIRONMENT] (INFO) : Environment created successfully.
# Simulation Progress [Episode 1]:  16%|█▌        | 16/100 [00:10<00:03, 21.08%/s, 16% completed]

# %%
env = NormalizeObservation(env)
env = NormalizeAction(env)
env = LoggerWrapper(env)
env = CSVLogger(env)

# run = wandb.init(entity='ojun-info-alpha',
#            project='final',
#            name='first',
#            settings=wandb.Settings(init_timeout=120.0))
# Discomment the following line to log to WandB (remember to set the API key as an environment variable)
# env = WandBLogger(env,
#                  entity='ojun-info-alpha',
#                  project_name='final',
#                  run_name='first',
#                  save_code = True,
#                  dump_frequency = 1000,
#                  artifact_save = False)

eval_env = NormalizeObservation(eval_env)
eval_env = NormalizeAction(eval_env)
eval_env = LoggerWrapper(eval_env)
eval_env = CSVLogger(eval_env)

# In this case, all the hyperparameters are the default ones
model = PPO(
    'MlpPolicy',
    env,
    verbose=1,
    device='cpu',
)

callbacks = []

# Set up Evaluation logging and saving best model
eval_callback = LoggerEvalCallback(
    eval_env=eval_env,
    train_env=env,
    n_eval_episodes=5,
    eval_freq_episodes=10,
    deterministic=True)

callbacks.append(eval_callback)
callback = CallbackList(callbacks)

timesteps = episodes * (env.get_wrapper_attr('timestep_per_episode') - 1)

# wandb logger and setting in SB3
if is_wrapped(env, WandBLogger):
    logger = SB3Logger(
        folder=None,
        output_formats=[
            HumanOutputFormat(
                sys.stdout,
                max_length=200),
            WandBOutputFormat()])
    model.set_logger(logger)

model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=100)
# Out:
# [WRAPPER NormalizeObservation] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeAction] (INFO) : New normalized action space: Box(-1.0, 1.0, (2,), float32)
# [WRAPPER NormalizeAction] (INFO) : Wrapper initialized.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.
# [WRAPPER CSVLogger] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeObservation] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeAction] (INFO) : New normalized action space: Box(-1.0, 1.0, (2,), float32)
# [WRAPPER NormalizeAction] (INFO) : Wrapper initialized.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.
# [WRAPPER CSVLogger] (INFO) : Wrapper initialized.
# Simulation Progress [Episode 1]:  16%|█▌        | 16/100 [00:12<00:03, 21.08%/s, 16% completed]Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 1: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-1/output.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 1 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 1]: 100%|██████████| 100/100 [00:09<00:00, 10.46%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 2: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-2/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 2 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 2]: 100%|██████████| 100/100 [00:09<00:00, 10.71%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 3: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-3/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 3 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 3]: 100%|██████████| 100/100 [00:10<00:00,  9.97%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 4: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-4/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 4 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 4]: 100%|██████████| 100/100 [00:09<00:00, 10.75%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 5: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-5/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 5 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 5]: 100%|██████████| 100/100 [00:09<00:00, 10.42%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 6: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-6/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 6 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 6]: 100%|██████████| 100/100 [00:10<00:00,  9.10%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 7: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-7/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 7 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 7]: 100%|██████████| 100/100 [00:09<00:00, 10.86%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 8: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-8/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 8 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 8]: 100%|██████████| 100/100 [00:09<00:00, 10.96%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 9: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-9/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 9 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 9]: 100%|██████████| 100/100 [00:09<00:00, 10.09%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 10: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-10/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 10 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 10]:  95%|█████████▌| 95/100 [00:07<00:00, 13.05%/s, 95% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 1: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-1/output.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 1 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 1]: 100%|██████████| 100/100 [00:07<00:00, 13.33%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 2: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-2/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 2 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 2]: 100%|██████████| 100/100 [00:08<00:00, 12.06%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 3: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-3/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 3 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 3]: 100%|██████████| 100/100 [00:07<00:00, 12.99%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 4: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-4/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 4 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 4]: 100%|██████████| 100/100 [00:07<00:00, 12.79%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 5: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-5/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 5 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=44630, episode_reward=-2.256461601152867 +/- 1.657194858155196
# [EVALUATION] (INFO) : New best mean reward!
# [EVALUATION] (INFO) : Save normalization calibration in evaluation folder
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 5]: 100%|██████████| 100/100 [00:08<00:00, 11.17%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 11: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-11/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 11 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 11]: 100%|██████████| 100/100 [00:10<00:00,  9.30%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 12: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-12/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 12 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 12]: 100%|██████████| 100/100 [00:12<00:00,  8.15%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 13: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-13/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 13 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 13]: 100%|██████████| 100/100 [00:11<00:00,  8.97%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 14: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-14/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 14 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 14]: 100%|██████████| 100/100 [00:10<00:00,  9.99%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 15: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-15/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 15 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 15]: 100%|██████████| 100/100 [00:09<00:00, 10.30%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 16: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-16/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 16 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 16]: 100%|██████████| 100/100 [00:09<00:00, 10.87%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 17: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-17/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 17 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 17]: 100%|██████████| 100/100 [00:10<00:00,  9.82%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 18: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-18/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 18 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 18]: 100%|██████████| 100/100 [00:10<00:00,  9.61%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 19: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-19/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 19 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 19]: 100%|██████████| 100/100 [00:09<00:00, 10.73%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 20: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-20/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 20 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 20]:  95%|█████████▌| 95/100 [00:07<00:00, 12.97%/s, 95% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 6: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-6/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 6 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 6]: 100%|██████████| 100/100 [00:07<00:00, 13.67%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 7: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-7/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 7 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 7]: 100%|██████████| 100/100 [00:07<00:00, 12.51%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 8: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-8/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 8 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 8]: 100%|██████████| 100/100 [00:07<00:00, 14.09%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 9: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-9/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 9 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 9]: 100%|██████████| 100/100 [00:07<00:00, 13.03%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 10: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-10/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 10 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=89260, episode_reward=-2.2643240704215355 +/- 1.6484480245341568
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 10]: 100%|██████████| 100/100 [00:07<00:00, 12.83%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 21: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-21/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 21 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 21]: 100%|██████████| 100/100 [00:09<00:00, 10.85%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 22: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-22/output.
# [SIMULATOR] (INFO) : handlers are ready.
# ...
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-96/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 96 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 96]: 100%|██████████| 100/100 [00:10<00:00,  9.25%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 97: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-97/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 97 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 97]: 100%|██████████| 100/100 [00:10<00:00,  9.91%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 98: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-98/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 98 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 98]: 100%|██████████| 100/100 [00:10<00:00,  9.98%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 99: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-99/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 99 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 99]: 100%|██████████| 100/100 [00:10<00:00,  9.56%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 100: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-100/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 100 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 100]:  95%|█████████▌| 95/100 [00:07<00:00, 12.64%/s, 95% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 46: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-46/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 46 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 46]: 100%|██████████| 100/100 [00:07<00:00, 13.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 47: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-47/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 47 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 47]: 100%|██████████| 100/100 [00:07<00:00, 13.30%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 48: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-48/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 48 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 48]: 100%|██████████| 100/100 [00:07<00:00, 13.53%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 49: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-49/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 49 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 49]: 100%|██████████| 100/100 [00:07<00:00, 13.42%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 50: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION-res1/episode-50/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 50 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=446300, episode_reward=-2.1897739993180254 +/- 1.6347348753093414
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 50]: 100%|██████████| 100/100 [00:07<00:00, 13.38%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 101: SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-100_2025-08-12_11:06-res1/episode-101/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 101 started.
# Simulation Progress [Episode 101]:   7%|▋         | 7/100 [00:00<00:00, 11795.95%/s, 7% completed]

# %%
model.save(env.get_wrapper_attr('workspace_path') + '/model')

# %%
env.close()
eval_env.close()
#env.wandb_run.finish()
# Out:
# Simulation Progress [Episode 35]: 100%|██████████| 100/100 [00:21<00:00, 25.83%/s, 100% completed]

# %%
random_env = gym.make(environment,
               env_name="EMPTY_A",
               weather_files=["JPN_Nagoya.476350_IWEC.epw"],
               reward=LinearReward,
               reward_kwargs = {
                   "energy_weight": 0.5,
                   'temperature_variables': ['perimeter_bot_zn_1_air_temperature',
                     'perimeter_bot_zn_2_air_temperature',
                     'perimeter_bot_zn_3_air_temperature',
                     'perimeter_bot_zn_4_air_temperature',
                     'perimeter_mid_zn_1_air_temperature',
                     'perimeter_mid_zn_2_air_temperature',
                     'perimeter_mid_zn_3_air_temperature',
                     'perimeter_mid_zn_4_air_temperature',
                     'perimeter_top_zn_1_air_temperature',
                     'perimeter_top_zn_2_air_temperature',
                     'perimeter_top_zn_3_air_temperature',
                     'perimeter_top_zn_4_air_temperature',],
                   'energy_variables': ['HVAC_electricity_demand_rate'],
                   "range_comfort_winter": (20.0, 23.5),
                   "range_comfort_summer": (23.0, 26.0),
                   "lambda_energy": 0.0001,
               },
            building_config=extra_conf,
              action_space=gym.spaces.Box(
                low=0,
                high=0,
                shape=(2,))
)

random_env = NormalizeObservation(random_env)
random_env = NormalizeAction(random_env)
random_env = LoggerWrapper(random_env)
random_env = CSVLogger(random_env)
# Out:
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment.
# [ENVIRONMENT] (INFO) : Name: EMPTY_A
# #==============================================================================================#
# [MODEL] (INFO) : Working directory created: /workspace/EMPTY_A-res2
# [MODEL] (INFO) : Model Config is correct.
# [MODEL] (INFO) : Building model Output:Variable updated with defined variable names.
# [MODEL] (INFO) : Updated building model Output:Meter with meter names.
# [MODEL] (INFO) : Building configuration: runperiod updated to {'start_day': 1, 'start_month': 7, 'start_year': 2024, 'end_day': 31, 'end_month': 7, 'end_year': 2024, 'start_weekday': 6, 'n_steps_per_hour': 6}
# [MODEL] (INFO) : Updated episode length (seconds): 2678400.0
# [MODEL] (INFO) : Updated timestep size (seconds): 600.0
# [MODEL] (INFO) : Updated timesteps per episode: 4464
# [MODEL] (INFO) : Runperiod established.
# [MODEL] (INFO) : Episode length (seconds): 2678400.0
# [MODEL] (INFO) : timestep size (seconds): 600.0
# [MODEL] (INFO) : timesteps per episode: 4464
# [REWARD] (INFO) : Reward function initialized.
# [ENVIRONMENT] (INFO) : Environment created successfully.
# [WRAPPER NormalizeObservation] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeAction] (INFO) : New normalized action space: Box(-1.0, 1.0, (2,), float32)
# [WRAPPER NormalizeAction] (INFO) : Wrapper initialized.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.
# [WRAPPER CSVLogger] (INFO) : Wrapper initialized.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:02<00:01, 80.14%/s, 10% completed]ed]
# /usr/local/lib/python3.12/dist-packages/gymnasium/utils/passive_env_checker.py:54: UserWarning: WARN: A Box action space maximum and minimum values are equal.
#   logger.warn("A Box action space maximum and minimum values are equal.")

# %%
# random agent
mean_rewards = []
for i in range(10):
    obs, info = random_env.reset()
    rewards = []
    truncated = terminated = False
    current_month = 0
    while not (terminated or truncated):
        a = random_env.action_space.sample()
        obs, reward, terminated, truncated, info = random_env.step(a)

        rewards.append(reward)
        if info['month'] != current_month:  # display results every month
            current_month = info['month']
            print('Reward: ', sum(rewards), info)

    mean_rewards.append(np.mean(rewards))

print(f"mean reward: {np.mean(mean_rewards)}")
# Out:
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 1: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-1/output.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 1 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:04<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 1]: 100%|██████████| 100/100 [00:07<00:00, 14.14%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 2: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-2/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 2 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:12<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 2]: 100%|██████████| 100/100 [00:06<00:00, 16.47%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 3: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-3/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 3 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:19<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 3]: 100%|██████████| 100/100 [00:06<00:00, 16.00%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 4: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-4/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 4 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:26<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 4]: 100%|██████████| 100/100 [00:06<00:00, 16.42%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 5: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-5/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 5 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:34<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 5]: 100%|██████████| 100/100 [00:06<00:00, 14.38%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 6: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-6/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 6 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:42<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 6]: 100%|██████████| 100/100 [00:06<00:00, 16.08%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 7: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-7/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 7 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:49<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 7]: 100%|██████████| 100/100 [00:06<00:00, 16.35%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 8: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-8/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 8 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [00:56<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 8]: 100%|██████████| 100/100 [00:06<00:00, 16.21%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 9: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-9/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 9 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [01:03<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 9]: 100%|██████████| 100/100 [00:07<00:00, 13.22%/s, 100% completed]]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 10: EMPTY_A
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/EMPTY_A-res2/episode-10/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 10 started.
# Simulation Progress [Episode 8]:  10%|█         | 10/100 [01:12<00:01, 80.14%/s, 10% completed]Reward:  -0.010059948897039251 {'time_elapsed(hours)': 0.3333333333333333, 'month': 7, 'day': 1, 'hour': 0, 'is_raining': False, 'action': [0.0, 0.0], 'timestep': 1, 'reward': -0.010059948897039251, 'energy_term': -0.010059948897039251, 'comfort_term': 0.0, 'energy_penalty': -201.19897794078503, 'comfort_penalty': 0, 'total_power_demand': 201.19897794078503, 'total_temperature_violation': 0, 'reward_weight': 0.5}
# Simulation Progress [Episode 10]: 100%|██████████| 100/100 [00:04<00:00, 24.06%/s, 100% completed]mean reward: -2.191271072543062
# Simulation Progress [Episode 10]: 100%|██████████| 100/100 [00:19<00:00, 24.06%/s, 100% completed]

# %%
env.close()
# Out:
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 7]: 100%|██████████| 100/100 [00:38<00:00,  2.60%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-5_2025-08-10_21:56]

# %%
eval_env.close()
# Out:
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-5_2025-08-10_21:56_EVALUATION]
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# [ENVIRONMENT] (INFO) : Environment closed. [SB3_PPO-Eplus-office-mixed-continuous-stochastic-v1-episodes-5_2025-08-10_21:56]
