# %%
import sys
from datetime import datetime

import gymnasium as gym
import numpy as np
import wandb
from stable_baselines3 import *
from stable_baselines3.common.callbacks import CallbackList
from stable_baselines3.common.logger import HumanOutputFormat
from stable_baselines3.common.logger import Logger as SB3Logger

import sinergym
from sinergym.utils.callbacks import *
from sinergym.utils.constants import *
from sinergym.utils.logger import WandBOutputFormat
from sinergym.utils.rewards import *
from sinergym.utils.wrappers import *

# %%
from stable_baselines3.common.env_util import make_vec_env

# %%
# Environment ID
environment = 'Eplus-5zone-mixed-continuous-stochastic-v1'

# Training episodes
episodes = 50

# Name of the experiment
experiment_date = datetime.today().strftime('%Y-%m-%d_%H:%M')
experiment_name = '5Z_LONG_SB3_PPO-' + environment + \
    '-episodes-' + str(episodes)
experiment_name += '_' + experiment_date

# %%
extra_conf = {
    'timesteps_per_hour': 6,
    'runperiod': (1, 4, 2024, 1, 3, 2025),
}

# %%
env = gym.make(environment,
               env_name=experiment_name,
               weather_files=["JPN_Nagoya.476350_IWEC.epw"],
               reward=ExpReward,
               reward_kwargs = {
                   "energy_weight": 0.5,
                   'temperature_variables': ['air_temperature'],
                   'energy_variables': ['HVAC_electricity_demand_rate'],
                   "range_comfort_winter": (18.0, 28.0),
                   "range_comfort_summer": (18.0, 28.0),
                   "lambda_energy": 0.0001,
               },
              building_config=extra_conf,)

eval_env = gym.make(environment,
                    env_name=experiment_name+'_EVALUATION',
                    weather_files=["JPN_Nagoya.476350_IWEC.epw"],
                    reward=ExpReward,
                    reward_kwargs = {
                        "energy_weight": 0.5,
                        'temperature_variables': ['air_temperature'],
                        'energy_variables': ['HVAC_electricity_demand_rate'],
                        "range_comfort_winter": (18.0, 28.0),
                        "range_comfort_summer": (18.0, 28.0),
                        "lambda_energy": 0.0001,
                    },
                   building_config=extra_conf,)
# Out:
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment.
# [ENVIRONMENT] (INFO) : Name: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #==============================================================================================#
# [MODEL] (INFO) : Working directory created: /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1
# [MODEL] (INFO) : Model Config is correct.
# [MODEL] (INFO) : Building model Output:Variable updated with defined variable names.
# [MODEL] (INFO) : Updated building model Output:Meter with meter names.
# [MODEL] (INFO) : Building configuration: runperiod updated to {'start_day': 1, 'start_month': 4, 'start_year': 2024, 'end_day': 1, 'end_month': 3, 'end_year': 2025, 'start_weekday': 1, 'n_steps_per_hour': 6}
# [MODEL] (INFO) : Updated episode length (seconds): 28944000.0
# [MODEL] (INFO) : Updated timestep size (seconds): 600.0
# [MODEL] (INFO) : Updated timesteps per episode: 48240
# [MODEL] (INFO) : Runperiod established.
# [MODEL] (INFO) : Episode length (seconds): 28944000.0
# [MODEL] (INFO) : timestep size (seconds): 600.0
# [MODEL] (INFO) : timesteps per episode: 48240
# [REWARD] (INFO) : Reward function initialized.
# [ENVIRONMENT] (INFO) : Environment created successfully.
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment.
# [ENVIRONMENT] (INFO) : Name: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #==============================================================================================#
# [MODEL] (INFO) : Working directory created: /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1
# [MODEL] (INFO) : Model Config is correct.
# [MODEL] (INFO) : Building model Output:Variable updated with defined variable names.
# [MODEL] (INFO) : Updated building model Output:Meter with meter names.
# [MODEL] (INFO) : Building configuration: runperiod updated to {'start_day': 1, 'start_month': 4, 'start_year': 2024, 'end_day': 1, 'end_month': 3, 'end_year': 2025, 'start_weekday': 1, 'n_steps_per_hour': 6}
# [MODEL] (INFO) : Updated episode length (seconds): 28944000.0
# [MODEL] (INFO) : Updated timestep size (seconds): 600.0
# [MODEL] (INFO) : Updated timesteps per episode: 48240
# [MODEL] (INFO) : Runperiod established.
# [MODEL] (INFO) : Episode length (seconds): 28944000.0
# [MODEL] (INFO) : timestep size (seconds): 600.0
# [MODEL] (INFO) : timesteps per episode: 48240
# [REWARD] (INFO) : Reward function initialized.
# [ENVIRONMENT] (INFO) : Environment created successfully.
# Simulation Progress [Episode 4]:   9%|▉         | 9/100 [00:23<00:56,  1.62%/s, 9% completed]

# %%
env = NormalizeObservation(env)
env = NormalizeAction(env)
env = LoggerWrapper(env)
env = CSVLogger(env)

eval_env = NormalizeObservation(eval_env)
eval_env = NormalizeAction(eval_env)
eval_env = LoggerWrapper(eval_env)
eval_env = CSVLogger(eval_env)

# In this case, all the hyperparameters are the default ones
model = PPO(
    'MlpPolicy',
    env,
    verbose=1,
    device='cpu',
    learning_rate=0.0003,
    gamma=0.9,
    batch_size=128,
    max_grad_norm=0.9,
    ent_coef=0,
)

callbacks = []

# Set up Evaluation logging and saving best model
eval_callback = LoggerEvalCallback(
    eval_env=eval_env,
    train_env=env,
    n_eval_episodes=2,
    eval_freq_episodes=5,
    deterministic=True)

callbacks.append(eval_callback)
callback = CallbackList(callbacks)

timesteps = episodes * (env.get_wrapper_attr('timestep_per_episode') - 1)

model.learn(
    total_timesteps=timesteps,
    callback=callback,
    log_interval=100)
# Out:
# [WRAPPER NormalizeObservation] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeAction] (INFO) : New normalized action space: Box(-1.0, 1.0, (2,), float32)
# [WRAPPER NormalizeAction] (INFO) : Wrapper initialized.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.
# [WRAPPER CSVLogger] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeObservation] (INFO) : Wrapper initialized.
# [WRAPPER NormalizeAction] (INFO) : New normalized action space: Box(-1.0, 1.0, (2,), float32)
# [WRAPPER NormalizeAction] (INFO) : Wrapper initialized.
# [WRAPPER LoggerWrapper] (INFO) : Wrapper initialized.
# [WRAPPER CSVLogger] (INFO) : Wrapper initialized.
# Simulation Progress [Episode 4]:   9%|▉         | 9/100 [00:24<00:56,  1.62%/s, 9% completed]Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 1: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-1/output.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 1 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 1]: 100%|██████████| 100/100 [00:57<00:00,  1.73%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 2: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-2/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 2 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 2]: 100%|██████████| 100/100 [00:57<00:00,  1.75%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 3: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-3/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 3 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 3]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 4: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-4/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 4 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 4]: 100%|██████████| 100/100 [00:56<00:00,  1.76%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 5: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-5/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 5 started.
# Simulation Progress [Episode 5]:  27%|██▋       | 27/100 [00:13<00:35,  2.06%/s, 27% completed]-----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.81e+04    |
# |    ep_rew_mean          | -3.7e+03    |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 100         |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.011128042 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.42        |
# |    value_loss           | 0.0201      |
# -----------------------------------------
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 5]: 100%|██████████| 100/100 [00:58<00:00,  1.72%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 6: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-6/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 6 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 6]:   2%|▏         | 2/100 [00:00<00:37,  2.60%/s, 2% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 1: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-1/output.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 1 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 1]: 100%|██████████| 100/100 [00:36<00:00,  2.73%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 2: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-2/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 2 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=241195, episode_reward=-0.07105596354882733 +/- 0.18525207110204822
# [EVALUATION] (INFO) : New best mean reward!
# [EVALUATION] (INFO) : Save normalization calibration in evaluation folder
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 2]: 100%|██████████| 100/100 [00:36<00:00,  2.78%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 7: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-7/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 7 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 7]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 8: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-8/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 8 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 8]: 100%|██████████| 100/100 [00:55<00:00,  1.79%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 9: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-9/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 9 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 9]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 10: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-10/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 10 started.
# Simulation Progress [Episode 10]:  51%|█████     | 51/100 [00:26<00:24,  2.00%/s, 51% completed]-----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.82e+04    |
# |    ep_rew_mean          | -3.47e+03   |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 200         |
# |    time_elapsed         | 565         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.011222076 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.252      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00704     |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.00802    |
# |    std                  | 0.302       |
# |    value_loss           | 0.0269      |
# -----------------------------------------
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 10]: 100%|██████████| 100/100 [00:56<00:00,  1.76%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 11: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-11/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 11 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 11]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 12: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-12/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 12 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 12]:   2%|▏         | 2/100 [00:00<00:26,  3.64%/s, 2% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 3: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-3/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 3 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 3]: 100%|██████████| 100/100 [00:35<00:00,  2.80%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 4: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-4/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 4 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=482390, episode_reward=-0.06451707513472021 +/- 0.16790588180950872
# [EVALUATION] (INFO) : New best mean reward!
# [EVALUATION] (INFO) : Save normalization calibration in evaluation folder
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 4]: 100%|██████████| 100/100 [00:35<00:00,  2.78%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 13: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-13/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 13 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 13]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 14: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-14/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 14 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 14]: 100%|██████████| 100/100 [00:57<00:00,  1.75%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 15: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-15/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 15 started.
# Simulation Progress [Episode 15]:  75%|███████▌  | 75/100 [00:40<00:14,  1.72%/s, 75% completed]------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.82e+04     |
# |    ep_rew_mean          | -3.28e+03    |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 300          |
# |    time_elapsed         | 883          |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0153452745 |
# |    clip_fraction        | 0.184        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.293        |
# |    explained_variance   | 0.347        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00175     |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | -0.00454     |
# |    std                  | 0.25         |
# |    value_loss           | 0.0104       |
# ------------------------------------------
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 15]: 100%|██████████| 100/100 [00:56<00:00,  1.76%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 16: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-16/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 16 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 16]: 100%|██████████| 100/100 [00:57<00:00,  1.75%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 17: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-17/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 17 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 17]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 18: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-18/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 18 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 18]:   2%|▏         | 2/100 [00:00<00:27,  3.62%/s, 2% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 5: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-5/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 5 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 5]: 100%|██████████| 100/100 [00:36<00:00,  2.76%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 6: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-6/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 6 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=723585, episode_reward=-0.05965546761375684 +/- 0.14381315353008267
# [EVALUATION] (INFO) : New best mean reward!
# [EVALUATION] (INFO) : Save normalization calibration in evaluation folder
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 6]: 100%|██████████| 100/100 [00:36<00:00,  2.78%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 19: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-19/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 19 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 19]: 100%|██████████| 100/100 [00:56<00:00,  1.76%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 20: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-20/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 20 started.
# Simulation Progress [Episode 20]:  99%|█████████▉| 99/100 [00:53<00:00,  2.11%/s, 99% completed]-----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.82e+04    |
# |    ep_rew_mean          | -3.16e+03   |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 400         |
# |    time_elapsed         | 1201        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.021236617 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.672       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.024       |
# |    n_updates            | 3990        |
# |    policy_gradient_loss | -0.00735    |
# |    std                  | 0.214       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 20]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 21: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-21/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 21 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 21]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 22: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-22/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 22 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 22]: 100%|██████████| 100/100 [00:57<00:00,  1.74%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 23: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# ...
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-18/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 18 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=2170755, episode_reward=-0.05794009291267527 +/- 0.13597461108917575
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 18]: 100%|██████████| 100/100 [00:38<00:00,  2.56%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 55: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-55/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 55 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 55]: 100%|██████████| 100/100 [01:04<00:00,  1.55%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 56: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-56/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 56 started.
# Simulation Progress [Episode 56]:  71%|███████   | 71/100 [00:42<00:13,  2.09%/s, 71% completed]-----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.82e+04    |
# |    ep_rew_mean          | -2.84e+03   |
# | time/                   |             |
# |    fps                  | 650         |
# |    iterations           | 1100        |
# |    time_elapsed         | 3463        |
# |    total_timesteps      | 2252800     |
# | train/                  |             |
# |    approx_kl            | 0.036966406 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 2.22        |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 10990       |
# |    policy_gradient_loss | -0.0066     |
# |    std                  | 0.0886      |
# |    value_loss           | 0.00526     |
# -----------------------------------------
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 56]: 100%|██████████| 100/100 [01:02<00:00,  1.60%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 57: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-57/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 57 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 57]: 100%|██████████| 100/100 [01:06<00:00,  1.50%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 58: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-58/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 58 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 58]: 100%|██████████| 100/100 [01:00<00:00,  1.64%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 59: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-59/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 59 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 59]: 100%|██████████| 100/100 [01:01<00:00,  1.63%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 60: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-60/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 60 started.
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 60]:   2%|▏         | 2/100 [00:00<00:30,  3.26%/s, 2% completed]]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 19: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-19/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 19 started.
# [WRAPPER CSVLogger] (INFO) : End of episode detected, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 19]: 100%|██████████| 100/100 [00:38<00:00,  2.57%/s, 100% completed]
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 20: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION-res1/episode-20/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 20 started.
# [EVALUATION] (INFO) : Evaluation num_timesteps=2411950, episode_reward=-0.05528392461322514 +/- 0.1306887562246772
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 20]: 100%|██████████| 100/100 [00:38<00:00,  2.57%/s, 100% completed]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION]
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode.
# [ENVIRONMENT] (INFO) : Episode 61: 5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37
# #----------------------------------------------------------------------------------------------#
# [MODEL] (INFO) : Episode directory created.
# [MODEL] (INFO) : Weather file JPN_Nagoya.476350_IWEC.epw used.
# [MODEL] (INFO) : Adapting weather to building model.
# [MODEL] (INFO) : Weather noise applied to columns: ['Dry Bulb Temperature']
# [ENVIRONMENT] (INFO) : Saving episode output path in /workspace/5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/episode-61/output.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# [ENVIRONMENT] (INFO) : Episode 61 started.
# Simulation Progress [Episode 61]:   2%|▏         | 2/100 [00:00<00:06, 14.52%/s, 2% completed]
# Simulation Progress [Episode 61]:   2%|▏         | 2/100 [00:19<00:06, 14.52%/s, 2% completed]

# %%
env.close()
eval_env.close()
# Out:
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# Simulation Progress [Episode 61]:   2%|▏         | 2/100 [00:59<48:48, 29.89s/%, 2% completed]]
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37]
# [WRAPPER CSVLogger] (INFO) : Environment closed, data updated in monitor and progress.csv.
# [WRAPPER NormalizeObservation] (INFO) : Normalization calibration saved.
# [ENVIRONMENT] (INFO) : Environment closed. [5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37_EVALUATION]
# Simulation Progress [Episode 4]:   9%|▉         | 9/100 [1:03:58<00:56,  1.62%/s, 9% completed]

# %%
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
with open("5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/progress.csv") as f:
    reader = csv.DictReader(f)
    mean_rewards = []
    mean_comforts = []
    mean_energys = []
    for row in reader:
        mean_rewards.append(float(row["mean_reward"]))
        mean_comforts.append(float(row["mean_reward_comfort_term"]))
        mean_energys.append(float(row["mean_reward_energy_term"]))

# %%
episodes = 50
plt.plot(np.arange(1,episodes+1,1), mean_rewards[:episodes], marker="o")
plt.xlabel("episodes num")
plt.ylabel("mean reward")
plt.show()

# %%
with open("5Z_LONG_SB3_PPO-Eplus-5zone-mixed-continuous-stochastic-v1-episodes-50_2025-08-14_14:37-res1/evaluation/evaluation_metrics.csv") as f:
    reader = csv.DictReader(f)
    mean_rewards = []
    mean_comforts = []
    mean_energys = []
    for row in reader:
        mean_rewards.append(float(row["mean_reward"]))
        mean_comforts.append(float(row["mean_reward_comfort_term"]))
        mean_energys.append(float(row["mean_reward_energy_term"]))

# %%
evals = 10

# %%
plt.plot(np.arange(1,evals+1,1), mean_rewards, marker="o")
plt.xlabel("evaluation num")
plt.ylabel("mean reward")
plt.xticks(np.arange(1,11,1))
plt.show()

# %%
plt.plot(np.arange(1, evals+1, 1), mean_comforts, marker="o")
plt.xlabel("evaluation num")
plt.ylabel("mean comfort reward")
plt.xticks(np.arange(1,11,1))
plt.show()

# %%
plt.plot(np.arange(1,evals+1,1), mean_energys, marker="o")
plt.xlabel("evaluation num")
plt.ylabel("mean energy reward")
plt.xticks(np.arange(1,11,1))
plt.show()
